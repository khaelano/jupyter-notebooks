# %% [markdown]
# Soal no.1 $\int_{3}^{7}5+7+\frac{5}{6} dx$

# %%
5*2
# Out:
# 10

# %%
3+2
# Out:
# 5

# %%
17-9
# Out:
# 8

# %%
3**4
# Out:
# 81

# %%
pow(3, 4)
# Out:
# 81

# %%
import math

# %%
math.sqrt(9)
# Out:
# 3.0
