# %%
3 + 5
# Out:
# 8

# %%
from sympy import ask, Q, I, oo

ask(Q.nonzero(oo))
# Out:
# False

# %%
type(8)
# Out:
# int

# %%
type(1.56)
# Out:
# float

# %%
type(3+4i)
# Out:
#   File "<ipython-input-6-77feda475753>", line 1
#     type(3+4i)
#            ^
# SyntaxError: invalid decimal literal

# %%
type(3+4j)
# Out:
# complex

# %%
type("Hello world!")
# Out:
# str

# %%
type('Hello world!')
# Out:
# str

# %%
type(['apple', 'banana', 'watermelon'])
# Out:
# list

# %%
type((10, 15, 20))
# Out:
# tuple

# %%
type(range(91))
# Out:
# range

# %%
type(bool(5))
# Out:
# bool

# %%
dict(name='JOhn', age=15)
# Out:
# {'name': 'JOhn', 'age': 15}

# %%
type(set({'apple', 'banana', 'bear'}))
# Out:
# set

# %%
bin_num = 0b10 ## tambah prefix 0b untuk menyatakan biner
bin_num = 0b100_000_111_101_111 ## underscore untuk memberikan pemisah
print(bin_num)
# Out:
# 16879

# %%
oct_num = 0o10 ## tambah prefix 0o untuk menytakan octal
print(oct_num)
# Out:
# 8

# %%
hex_num = 0xF9 ## tambah prefix 0x untuk menyatakan hex
print(hex_num)
# Out:
# 249

# %%
i = 255
print(bin(i))
print(oct(i))
print(hex(i))
# Out:
# 0b11111111
# 0o377
# 0xff

# %%
i = 255
print(format(i, 'b'))
print(format(i, 'o'))
print(format(i, 'x'))
# Out:
# 11111111
# 377
# ff

# %%
i = 255
print(format(i, '#b'))
print(format(i, '#o'))
print(format(i, '#x'))
# Out:
# 0b11111111
# 0o377
# 0xff

# %%
i = 255
print(format(i, '010b'))
print(format(i, '010o'))
print(format(i, '010x'))
# Out:
# 0011111111
# 0000000377
# 00000000ff

# %%
i = 255
print(format(i, '#010b'))
print(format(i, '#010o'))
print(format(i, '#010x'))
# Out:
# 0b11111111
# 0o00000377
# 0x000000ff
